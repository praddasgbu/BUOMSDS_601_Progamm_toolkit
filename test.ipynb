# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fruit_df = pd.DataFrame(
    {
        "color":  ["red", "orange", "purple"],
        "flavor": [3, 3, 4],
        "score":  [3, 2, 4]
    },
    index = ["apple", "orange", "grape"]
)

# %%
fruit_df
# Out:
#          color  flavor  score
# apple      red       3      3
# orange  orange       3      2
# grape   purple       4      4
